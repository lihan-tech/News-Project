# %%
print("in this selenium code add in future")

# %%
#this is the code for csv file name to News.csv
import os

# Folder path where the CSV file is located
folder_path = r'C:\Users\bomma\Desktop\Github\News'

# Loop through the files in the folder
for filename in os.listdir(folder_path):
    # Check if the file is a CSV file
    if filename.endswith('.csv'):
        # Full path to the old file
        old_file_path = os.path.join(folder_path, filename)
        
        # Full path to the new file name
        new_file_path = os.path.join(folder_path, 'News.csv')
        
        # Rename the file
        os.rename(old_file_path, new_file_path)
        print(f'Renamed "{filename}" to "News.csv"')
        break  # Stop after renaming the first CSV file found

# If no CSV file was found, you can add a message
else:
    print("No CSV file found in the specified folder.")
# Out:
# Renamed "CF-AN-equities-28-10-2025-to-31-10-2025.csv" to "News.csv"

# %%
#new code for removing column FILE SIZE in csv file 22-05-2025
import pandas as pd

def remove_file_size_column(file_path: str) -> None:
    """
    Removes the 'FILE SIZE' column from the CSV file and overwrites the original file.

    Parameters
    ----------
    file_path : str
        Full path of the CSV file to modify.

    Returns
    -------
    None
        The original CSV file is updated in place.
    """
    # Read the CSV file
    df = pd.read_csv(file_path)

    # Check if 'FILE SIZE' column exists
    if "FILE SIZE" in df.columns:
        # Drop the column
        df = df.drop(columns=["FILE SIZE"])
        print("'FILE SIZE' column removed.")
    else:
        print("No 'FILE SIZE' column found. No changes made.")

    # Overwrite the original file with the updated data
    df.to_csv(file_path, index=False)
    print(f"File overwritten successfully: {file_path}")

# Example usage
file_path = r'C:\Users\bomma\Desktop\Github\News\News.csv'
remove_file_size_column(file_path)
# Out:
# No 'FILE SIZE' column found. No changes made.
# File overwritten successfully: C:\Users\bomma\Desktop\Github\News\News.csv

# %% [markdown]
# #change column names
# import sqlite3
# import pandas as pd
#
# # --- File paths ---
# csv_path = r"C:\Users\bomma\Desktop\Github\News\News.csv"
# db_path = r"C:\Users\bomma\Desktop\Daily Reports\News\Raw All Year Corporate News\Raw All Corporate News.db"
# table_name = "All_news"
#
# # --- Step 1: Connect to database ---
# conn = sqlite3.connect(db_path)
# cursor = conn.cursor()
#
# # --- Step 2: Get column names from database table ---
# cursor.execute(f"PRAGMA table_info({table_name})")
# db_columns = [col[1] for col in cursor.fetchall()]  # extract only column names
# print("✅ Database columns:", db_columns)
#
# # --- Step 3: Read your CSV file ---
# df = pd.read_csv(csv_path)
# print("✅ Original CSV columns:", list(df.columns))
#
# # --- Step 4: Replace CSV column names one by one in order ---
# for i in range(min(len(df.columns), len(db_columns))):
#     df.columns.values[i] = db_columns[i]
#
# # --- Step 5: Save updated CSV file ---
# df.to_csv(csv_path, index=False)
# print(f"✅ CSV column names replaced (in order) with database table column names.")
# print(f"📁 Updated file saved at: {csv_path}")
#
# # --- Close connection ---
# conn.close()

# %%
#2 remove zip and xml and excel 
import os
import pandas as pd

def remove_specific_rows(file_path):
    # Read the CSV file into a pandas DataFrame
    df = pd.read_csv(file_path)
    
    # Remove rows where the ATTACHMENT column ends with ".xml", ".zip", or ".xlsx"
    df = df[~df['ATTACHMENT'].str.endswith(('.xml', '.zip', '.xlsx'))]
    
    # Save the updated DataFrame to the same CSV file
    df.to_csv(file_path, index=False)

# Function to process all CSV files in a folder
def process_csv_files(folder_path):
    # Iterate over all files in the folder
    for file_name in os.listdir(folder_path):
        if file_name.endswith('.csv'):
            file_path = os.path.join(folder_path, file_name)
            print("Processing:", file_path)
            
            # Read the CSV file
            df = pd.read_csv(file_path)
            
            # Remove rows where data in the "ATTACHMENT" column starts with "-"
            df = df[~df['ATTACHMENT'].str.startswith('-')]
            
            # Write the modified DataFrame back to the same CSV file
            df.to_csv(file_path, index=False)
            
            # Call the function to remove XML, ZIP, and XLSX rows
            remove_specific_rows(file_path)
            
            print("XML, ZIP, and XLSX rows removed successfully.")

# Folder path containing CSV files
folder_path = r"C:\Users\bomma\Desktop\Github\News"

# Call the function to process all CSV files in the folder
process_csv_files(folder_path)
# Out:
# Processing: C:\Users\bomma\Desktop\Github\News\News.csv
# XML, ZIP, and XLSX rows removed successfully.

# %%
#3 remove loss of certificate
import os
import pandas as pd

# Folder path
folder_path = r"C:\Users\bomma\Desktop\Github\News"

# List all files in the folder
file_names = os.listdir(folder_path)

# Iterate through each file in the folder
for file_name in file_names:
    # Check if the file is a CSV file
    if file_name.endswith('.csv'):
        # Construct the full file path
        file_path = os.path.join(folder_path, file_name)
        
        # Read the CSV file
        data = pd.read_csv(file_path)
        
        # Filter out rows containing "ESOP/ESOS/ESPS" or "Loss of Share Certificates" in the SUBJECT column
        filtered_data = data[~data['SUBJECT'].str.contains('ESOP/ESOS/ESPS|Loss of Share Certificates|Loss of share certificat|Loss of share certificate|ESOP/ESPS/SBEB Scheme|loss of share certificates')]
        
        # Overwrite the original file with the filtered data
        filtered_data.to_csv(file_path, index=False)
        
        print("Filtered data has been saved to", file_path)
# Out:
# Filtered data has been saved to C:\Users\bomma\Desktop\Github\News\News.csv

# %%
#4 pdf links extract
import pandas as pd
import os
import glob

# Input folder path containing CSV files
input_folder_path =  r"C:\Users\bomma\Desktop\Github\News"

# Output folder path for saving modified CSV files
output_folder_path = r"C:\Users\bomma\Desktop\Github\News"

# Get a list of all CSV files in the input folder
csv_files = glob.glob(os.path.join(input_folder_path, '*.csv'))

# Iterate over each CSV file
for file_path in csv_files:
    # Read the CSV file
    df = pd.read_csv(file_path)
    
    # Extract filenames from the "ATTACHMENT" column
    df['LINKS'] = df['ATTACHMENT'].apply(lambda x: x.split('/')[-1])
    
    # Construct the output file path
    output_file_path = os.path.join(output_folder_path, os.path.basename(file_path))
    
    # Save the modified DataFrame to the output CSV file
    df.to_csv(output_file_path, index=False)
    
    # Print a message indicating the operation is done for each file
    print(f"Filenames extracted and saved to the 'links' column in the CSV file: {output_file_path}")
# Out:
# Filenames extracted and saved to the 'links' column in the CSV file: C:\Users\bomma\Desktop\Github\News\News.csv

# %%
#5empty database create
import sqlite3
import os

# Define the folder path
folder_path = r"C:\Users\bomma\Desktop\Github\Database"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Construct the full file path for the SQLite database
db_file_path = os.path.join(folder_path, 'News Analysis.db')

# Create an empty SQLite database file
with sqlite3.connect(db_file_path) as conn:
    print("Database file created successfully at:", db_file_path)

# Close the connection
conn.close()
# Out:
# Database file created successfully at: C:\Users\bomma\Desktop\Github\Database\News Analysis.db

# %%
#6 csv data add in database
import os
import pandas as pd
import sqlite3

# Folder path containing CSV files
csv_folder =  r"C:\Users\bomma\Desktop\Github\News"

# Database file path
db_file =  r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

# Function to create database table from CSV file
def create_table_from_csv(csv_file, cursor):
    table_name = os.path.splitext(os.path.basename(csv_file))[0]  # Extract table name from CSV file name
    df = pd.read_csv(csv_file)  # Read CSV file into DataFrame
    try:
        df.columns = ['SYMBOL', 'COMPANY NAME', 'SUBJECT', 'DETAILS', 'BROADCAST DATE/TIME', 'RECEIPT', 'DISSEMINATION', 'DIFFERENCE', 'ATTACHMENT', 'LINKS']  # Rename columns
    except ValueError:
        pass  # Ignore length mismatch error
    # Add "ID" column as the first column with auto-generated numbers
    df.insert(0, 'ID', range(1, len(df) + 1))
    df.to_sql(table_name, conn, if_exists='replace', index=False)  # Write DataFrame to SQLite database as a table

# Connect to SQLite database
conn = sqlite3.connect(db_file)
cursor = conn.cursor()

# Iterate over CSV files in the folder
for file_name in os.listdir(csv_folder):
    if file_name.endswith('.csv'):
        csv_file_path = os.path.join(csv_folder, file_name)
        create_table_from_csv(csv_file_path, cursor)

# Commit changes and close connection
conn.commit()
conn.close()

print("Database successfully created from CSV files with 'ID' column.")
# Out:
# Database successfully created from CSV files with 'ID' column.

# %%
#7 filter the news
import sqlite3

# Connect to the first database
try:
    conn1 = sqlite3.connect(r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db")
    cursor1 = conn1.cursor()
except sqlite3.Error as e:
    print("Error connecting to the first database:", e)

# Connect to the second database
try:
    conn2 = sqlite3.connect(r"C:\Users\bomma\Desktop\Github\My Stocks\MyStocks.db")
    cursor2 = conn2.cursor()
except sqlite3.Error as e:
    print("Error connecting to the second database:", e)

# Fetch symbols from the second database
try:
    cursor2.execute("SELECT SYMBOL FROM News")
    symbols = [row[0] for row in cursor2.fetchall()]
except sqlite3.Error as e:
    print("Error fetching symbols from the second database:", e)

# Delete rows from the first database where SYMBOL is not in symbols list
try:
    cursor1.execute("DELETE FROM News WHERE SYMBOL NOT IN ({})".format(','.join(['?']*len(symbols))), symbols)
    conn1.commit()
except sqlite3.Error as e:
    print("Error deleting rows from the first database:", e)
finally:
    conn1.close()
    conn2.close()

print("Operation completed successfully!")
# Out:
# Operation completed successfully!

# %%
#8this is the new code for csv data copy and paste in new excelfile 
import pandas as pd
import openpyxl

# Define the paths to your files
csv_file_path = r'C:\Users\bomma\Desktop\Github\News\News.csv'
excel_folder_path = r'C:\Users\bomma\Desktop\Github\Excel format news'
excel_file_name = 'Symbols.xlsx'
excel_file_path = f'{excel_folder_path}/{excel_file_name}'

# Load the CSV file
csv_data = pd.read_csv(csv_file_path)

# Extract the "ATTACHMENT" column data
attachment_data = csv_data['ATTACHMENT']

# Create a new workbook and select the active sheet
wb = openpyxl.Workbook()
sheet = wb.active
sheet.title = 'Sheet1'

# Write the "ATTACHMENT" column header and data to Sheet1
sheet.cell(row=1, column=1, value='ATTACHMENT')
for index, value in enumerate(attachment_data, start=2):
    sheet.cell(row=index, column=1, value=value)

# Save the new Excel file
wb.save(excel_file_path)

print(f"Data from 'ATTACHMENT' column in CSV file has been added to 'Sheet1' in the new Excel file '{excel_file_name}'.")
# Out:
# Data from 'ATTACHMENT' column in CSV file has been added to 'Sheet1' in the new Excel file 'Symbols.xlsx'.

# %%
print ("hello world")
# Out:
# hello world

# %%
#9th news download without chrome if internet there waiting
import http.client
import os
from urllib.parse import urlparse
import openpyxl
import threading
import time
import socket

# Path to the Excel file containing URLs
excel_file_path = r'C:\Users\bomma\Desktop\Github\Excel format news\Symbols.xlsx'

# Function to check internet connection
def is_connected(host="8.8.8.8", port=53, timeout=3):
    try:
        socket.setdefaulttimeout(timeout)
        socket.socket(socket.AF_INET, socket.SOCK_STREAM).connect((host, port))
        return True
    except socket.error as ex:
        print(f"Internet connection lost: {ex}")
        return False

# Function to download a file with a 2-minute timeout
def download_file(url, save_path, timeout=120):
    try:
        # Ensure the directory exists or create it if it doesn't
        os.makedirs(os.path.dirname(save_path), exist_ok=True)

        # Parse the URL to get hostname and resource path
        parsed_url = urlparse(url)
        hostname = parsed_url.hostname
        resource_path = parsed_url.path

        # Connect to the server using HTTPS with a 2-minute timeout
        conn = http.client.HTTPSConnection(hostname, timeout=timeout)

        # Send a GET request to download the file
        conn.request("GET", resource_path)

        # Get the response from the server
        response = conn.getresponse()

        # Check if the request was successful (status code 200)
        if response.status == 200:
            # Open the file and write the response content (the file content)
            with open(save_path, 'wb') as f:
                f.write(response.read())
            print(f"Downloaded successfully to {save_path}")
        else:
            print(f"Failed to download file {os.path.basename(save_path)}. HTTP status code: {response.status}")

        # Close the connection
        conn.close()

    except Exception as e:
        # Handle any errors during the download process
        print(f"An error occurred while downloading {os.path.basename(save_path)}: {e}")

# Function to handle the downloading process for each URL
def process_url(row, url, save_path):
    print(f"Starting download for {url} at row {row}")
    
    # Check internet connection and wait if it's lost
    while not is_connected():
        print("Waiting for internet connection to be restored...")
        time.sleep(30)  # Wait for 30 seconds before checking again
    
    download_file(url, save_path)
    print(f"Completed download for {url} at row {row}")

# Load URLs from the Excel file and download each one using multi-threading
try:
    # Open the workbook in read-only mode
    wb = openpyxl.load_workbook(filename=excel_file_path, read_only=True)

    # Load the first sheet named 'Sheet1'
    sheet = wb['Sheet1']

    # Detect the last row with data in column 'A'
    max_row = sheet.max_row

    # List to keep track of threads
    threads = []

    # Iterate through the rows to get each URL and download the corresponding file
    for row in range(2, max_row + 1):  # Start from row 2 and go up to the last row with data
        cell_value = sheet[f'A{row}'].value  # Read value from column A
        if cell_value:  # Check if the cell is not empty
            url = cell_value.strip()  # Remove any extra spaces around the URL
            save_path = rf"C:\Users\bomma\Desktop\Github\All download pdfs\{os.path.basename(urlparse(url).path)}"
            
            # Create a new thread for each download
            thread = threading.Thread(target=process_url, args=(row, url, save_path))
            threads.append(thread)
            thread.start()  # Start the thread

            # Optional: Limit the number of concurrent threads to avoid overloading the system
            while threading.active_count() > 10:
                time.sleep(1)  # Wait for some threads to finish

    # Wait for all threads to complete
    for thread in threads:
        thread.join()

except Exception as e:
    # Handle errors that occur while reading the Excel file
    print(f"An error occurred while reading the Excel file: {e}")
# Out:
# Starting download for https://nsearchives.nseindia.com/corporate/DDEL_31102025232615_BSENSESIGNED.pdf at row 2
# Starting download for https://nsearchives.nseindia.com/corporate/SIMBHALS_31102025231925_Letter_sd.pdf at row 3
# Starting download for https://nsearchives.nseindia.com/corporate/SYMPHONY_31102025231406_Con_Call_31_10_2025.pdf at row 4
# Starting download for https://nsearchives.nseindia.com/corporate/yashpakka_31102025231229_2510_Investor_Call_Intimation.pdf at row 5
# Starting download for https://nsearchives.nseindia.com/corporate/SYMPHONY_31102025230354_Letter_for_Stock_Exchange_31_10_2025.pdf at row 6
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\SYMPHONY_31102025231406_Con_Call_31_10_2025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/SYMPHONY_31102025231406_Con_Call_31_10_2025.pdf at row 4
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\yashpakka_31102025231229_2510_Investor_Call_Intimation.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/yashpakka_31102025231229_2510_Investor_Call_Intimation.pdf at row 5
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\SYMPHONY_31102025230354_Letter_for_Stock_Exchange_31_10_2025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/SYMPHONY_31102025230354_Letter_for_Stock_Exchange_31_10_2025.pdf at row 6
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\SIMBHALS_31102025231925_Letter_sd.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/SIMBHALS_31102025231925_Letter_sd.pdf at row 3
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\DDEL_31102025232615_BSENSESIGNED.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/DDEL_31102025232615_BSENSESIGNED.pdf at row 2
# Starting download for https://nsearchives.nseindia.com/corporate/GABRIEL_31102025224434_SEIntimation_Reg29_signed.pdf at row 7
# Starting download for https://nsearchives.nseindia.com/corporate/MARUTIASHISH_31102025224351_StxIntimation_AudioRecording_30Sep2025.pdf at row 8
# Starting download for https://nsearchives.nseindia.com/corporate/NACLIND_31102025224233_SEINTIMATIONPB31102025.pdf at row 9
# Starting download for https://nsearchives.nseindia.com/corporate/HCL-INSYS1_31102025224015_HCLI__1_.pdf at row 10
# Starting download for https://nsearchives.nseindia.com/corporate/NAZARA_31102025221554_IntimationChangeinRO.pdf at row 11
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\MARUTIASHISH_31102025224351_StxIntimation_AudioRecording_30Sep2025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/MARUTIASHISH_31102025224351_StxIntimation_AudioRecording_30Sep2025.pdf at row 8
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\GABRIEL_31102025224434_SEIntimation_Reg29_signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/GABRIEL_31102025224434_SEIntimation_Reg29_signed.pdf at row 7
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\NAZARA_31102025221554_IntimationChangeinRO.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/NAZARA_31102025221554_IntimationChangeinRO.pdf at row 11
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\HCL-INSYS1_31102025224015_HCLI__1_.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/HCL-INSYS1_31102025224015_HCLI__1_.pdf at row 10
# Starting download for https://nsearchives.nseindia.com/corporate/GODREJCP_31102025221152_SE_TDS_Cover_Letter-Signed.pdf at row 12
# Starting download for https://nsearchives.nseindia.com/corporate/FORCEMOTORS_31102025220119_IntimationofBoardMeeting.pdf at row 13
# Starting download for https://nsearchives.nseindia.com/corporate/YAARI_31102025220018_IB_Monitoring_Agency_31102025.pdf at row 14
# Starting download for https://nsearchives.nseindia.com/corporate/YAARI_31102025215908_IB_Monitoring_Agency_31102025.pdf at row 15
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\FORCEMOTORS_31102025220119_IntimationofBoardMeeting.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/FORCEMOTORS_31102025220119_IntimationofBoardMeeting.pdf at row 13
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\YAARI_31102025215908_IB_Monitoring_Agency_31102025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/YAARI_31102025215908_IB_Monitoring_Agency_31102025.pdf at row 15
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\YAARI_31102025220018_IB_Monitoring_Agency_31102025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/YAARI_31102025220018_IB_Monitoring_Agency_31102025.pdf at row 14
# Starting download for https://nsearchives.nseindia.com/corporate/COFORGE_31102025215806_Transcript_Intimation.pdf at row 16
# Starting download for https://nsearchives.nseindia.com/corporate/VEDL_31102025215444_4VEDL_SEIntimation_ConferenceCall_RecordingLink_signed.pdf at row 17
# Starting download for https://nsearchives.nseindia.com/corporate/SGLTPL_31102025215329_SHA_and_BTA_Intimation.pdf at row 18
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\VEDL_31102025215444_4VEDL_SEIntimation_ConferenceCall_RecordingLink_signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/VEDL_31102025215444_4VEDL_SEIntimation_ConferenceCall_RecordingLink_signed.pdf at row 17
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\COFORGE_31102025215806_Transcript_Intimation.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/COFORGE_31102025215806_Transcript_Intimation.pdf at row 16
# Starting download for https://nsearchives.nseindia.com/corporate/CLNINDIA_31102025214256_HCILBMOutcome310125SIGNED.pdf at row 19
# Starting download for https://nsearchives.nseindia.com/corporate/MHRIL_31102025214348_SE_Earnings_calls_outcome_Intimation_signed.pdf at row 20
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\SGLTPL_31102025215329_SHA_and_BTA_Intimation.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/SGLTPL_31102025215329_SHA_and_BTA_Intimation.pdf at row 18
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\MHRIL_31102025214348_SE_Earnings_calls_outcome_Intimation_signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/MHRIL_31102025214348_SE_Earnings_calls_outcome_Intimation_signed.pdf at row 20
# Starting download for https://nsearchives.nseindia.com/corporate/YAARI_31102025214328_IB_BM_Outcome_31102025.pdf at row 21
# Starting download for https://nsearchives.nseindia.com/corporate/YAARI_31102025214159_IB_BM_Outcome_31102025.pdf at row 22
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\GODREJCP_31102025221152_SE_TDS_Cover_Letter-Signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/GODREJCP_31102025221152_SE_TDS_Cover_Letter-Signed.pdf at row 12
# Starting download for https://nsearchives.nseindia.com/corporate/YAARI_31102025214013_IB_BM_Outcome_31102025.pdf at row 23
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\NACLIND_31102025224233_SEINTIMATIONPB31102025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/NACLIND_31102025224233_SEINTIMATIONPB31102025.pdf at row 9
# Starting download for https://nsearchives.nseindia.com/corporate/SYNGENE3_31102025213827_Investorcallinitimation_November62025_Signed.pdf at row 24
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\CLNINDIA_31102025214256_HCILBMOutcome310125SIGNED.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/CLNINDIA_31102025214256_HCILBMOutcome310125SIGNED.pdf at row 19
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\SYNGENE3_31102025213827_Investorcallinitimation_November62025_Signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/SYNGENE3_31102025213827_Investorcallinitimation_November62025_Signed.pdf at row 24
# Starting download for https://nsearchives.nseindia.com/corporate/YAARI_31102025213651_IB_BM_Outcome_31102025.pdf at row 25
# Starting download for https://nsearchives.nseindia.com/corporate/RELIGARE_31102025213324_RELUPDATE31102025.pdf at row 26
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\YAARI_31102025213651_IB_BM_Outcome_31102025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\Himanshugail_31102025210947_Audiorecordingsintimation.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/Himanshugail_31102025210947_Audiorecordingsintimation.pdf at row 37
# Starting download for https://nsearchives.nseindia.com/corporate/MEGASOFT_31102025211034_Disclosurereg30.pdf at row 38
# Starting download for https://nsearchives.nseindia.com/corporate/AEGISCHEM_31102025210606_ALL_Postalballotnotice_S.pdf at row 39
# Starting download for https://nsearchives.nseindia.com/corporate/Mathew_31102025210549_BSENSE_Audiolink__ConferenceCall_Q2_FY_25_26.pdf at row 40
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\MEGASOFT_31102025211034_Disclosurereg30.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/MEGASOFT_31102025211034_Disclosurereg30.pdf at row 38
# Starting download for https://nsearchives.nseindia.com/corporate/REPRO_31102025210406_Reply_NSE_Spurt_in_Volume.pdf at row 41
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\Mathew_31102025210549_BSENSE_Audiolink__ConferenceCall_Q2_FY_25_26.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/Mathew_31102025210549_BSENSE_Audiolink__ConferenceCall_Q2_FY_25_26.pdf at row 40
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\REPRO_31102025210406_Reply_NSE_Spurt_in_Volume.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/REPRO_31102025210406_Reply_NSE_Spurt_in_Volume.pdf at row 41
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\YAARI_31102025211756_IB_BM_Outcome_31102025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/YAARI_31102025211756_IB_BM_Outcome_31102025.pdf at row 34
# Starting download for https://nsearchives.nseindia.com/corporate/AVTL_31102025210306_AVTL_Postalballot_Notice_Signed.pdf at row 42
# Starting download for https://nsearchives.nseindia.com/corporate/DCAL_31102025204932_IntimationofConCall31102025-Signed.pdf at row 43
# Starting download for https://nsearchives.nseindia.com/corporate/STRIDES_31102025204850_SE_Intimation_Earnings_Call_Audio.pdf at row 44
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\AEGISCHEM_31102025210606_ALL_Postalballotnotice_S.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/AEGISCHEM_31102025210606_ALL_Postalballotnotice_S.pdf at row 39
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\STRIDES_31102025204850_SE_Intimation_Earnings_Call_Audio.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/STRIDES_31102025204850_SE_Intimation_Earnings_Call_Audio.pdf at row 44
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\DCAL_31102025204932_IntimationofConCall31102025-Signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/DCAL_31102025204932_IntimationofConCall31102025-Signed.pdf at row 43
# Starting download for https://nsearchives.nseindia.com/corporate/STRIDES_31102025204505_SE_Intimation_Earnings_Call_Audio.pdf at row 45
# Starting download for https://nsearchives.nseindia.com/corporate/MAHLIFE1_31102025204516_OutcomeofBoardMeeting_-_Investor_PPT_SGD.pdf at row 46
# Starting download for https://nsearchives.nseindia.com/corporate/SPANDANA_31102025203335_SEAudiorecording31oct2025.pdf at row 47
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\AVTL_31102025210306_AVTL_Postalballot_Notice_Signed.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/AVTL_31102025210306_AVTL_Postalballot_Notice_Signed.pdf at row 42
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\STRIDES_31102025204505_SE_Intimation_Earnings_Call_Audio.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/STRIDES_31102025204505_SE_Intimation_Earnings_Call_Audio.pdf at row 45
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\SPANDANA_31102025203335_SEAudiorecording31oct2025.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/SPANDANA_31102025203335_SEAudiorecording31oct2025.pdf at row 47
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\CLNINDIA_31102025212055_HCILBMOutcome310125SIGNED.pdf
# Completed download for https://nsearchives.nseindia.com/corporate
pdf
# Completed download for https://nsearchives.nseindia.com/corporate/sanath_rao_janabank_com_28102025080331_Intimation_on_UB_Transition.pdf at row 2413
# Downloaded successfully to C:\Users\bomma\Desktop\Github\All download pdfs\MEGASOFT_28102025004140_Disclosure.pdf
# Completed download for https://nsearchives.nseindia.com/corporate/MEGASOFT_28102025004140_Disclosure.pdf at row 2414

# %% [markdown]
# #9 News extract
# import os
# import pandas as pd
# from PyPDF2 import PdfReader
# import sqlite3
# import openpyxl
# import time
# import requests
#
# def extract_text_from_pdf(file_path, start_texts, end_texts, max_words=750):
#     try:
#         with open(file_path, 'rb') as file:
#             reader = PdfReader(file)
#             full_text = ""
#             for page in reader.pages:
#                 full_text += page.extract_text()
#
#             start_index = -1
#             for start_text in start_texts:
#                 start_index = full_text.find(start_text)
#                 if start_index != -1:
#                     break
#
#             if start_index != -1:
#                 end_index = -1
#                 for end_text in end_texts:
#                     end_index = full_text.find(end_text, start_index)
#                     if end_index != -1:
#                         break
#
#                 if end_index != -1:
#                     extracted_text = full_text[start_index:end_index + len(end_text)]
#                     words = extracted_text.split()
#                     if len(words) > max_words:
#                         extracted_text = ' '.join(words[:max_words])
#                     return extracted_text
#
#             return full_text
#     except Exception as e:
#         print(f"An error occurred while processing {file_path}: {e}")
#         return None
#
# def update_database_with_extracted_text(folder_path, db_file_path, excel_file_path, start_texts, end_texts):
#     try:
#         table_name_df = pd.read_excel(excel_file_path, sheet_name='Ramu2', header=None, usecols="A", nrows=2)
#         table_name = table_name_df.iloc[1, 0]
#         conn = sqlite3.connect(db_file_path)
#         c = conn.cursor()
#         c.execute(f"PRAGMA table_info({table_name})")
#         columns = c.fetchall()
#         column_names = [col[1] for col in columns]
#         if 'NEWS' not in column_names:
#             c.execute(f"ALTER TABLE {table_name} ADD COLUMN NEWS TEXT")
#         c.execute(f"SELECT * FROM {table_name}")
#         rows = c.fetchall()
#         for row in rows:
#             pdf_file_name = str(row[10])
#             pdf_file_path = os.path.join(folder_path, pdf_file_name)
#             if os.path.exists(pdf_file_path):
#                 extracted_text = extract_text_from_pdf(pdf_file_path, start_texts, end_texts)
#                 if extracted_text is not None:
#                     c.execute(f"UPDATE {table_name} SET NEWS = ? WHERE LINKS = ?",
#                               (extracted_text, pdf_file_name))
#                     print(f"Text extracted successfully from: {pdf_file_name}")
#             else:
#                 print(f"PDF file '{pdf_file_name}' not found at path: {pdf_file_path}.")
#         conn.commit()
#         print("Update successful")
#         conn.close()
#     except Exception as e:
#         print(f"An error occurred while updating the database: {e}")
#
# def delete_row_from_excel(file_path, sheet_name, row_number):
#     try:
#         workbook = openpyxl.load_workbook(file_path)
#         sheet = workbook[sheet_name]
#         sheet.delete_rows(row_number)
#         workbook.save(file_path)
#         print(f"Row {row_number} deleted successfully from {sheet_name} sheet.")
#     except Exception as e:
#         print(f"An error occurred while deleting row: {e}")
#
# def send_telegram_message(token, chat_id, message):
#     url = f"https://api.telegram.org/bot{token}/sendMessage"
#     payload = {
#         "chat_id": chat_id,
#         "text": message
#     }
#     response = requests.post(url, json=payload)
#     if response.status_code == 200:
#         print("Message sent successfully!")
#     else:
#         print(f"Failed to send message. Status code: {response.status_code}")
#
# # Define file paths and parameters
# folder_path = r"C:\Users\bomma\Desktop\Github\All download pdfs"
# db_file_path = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"
# excel_file_path = r"C:\Users\bomma\Desktop\Daily Reports\News\News Download and extract\Single day Reports\Tickers\TICKERS.xlsx"
# start_texts = ["Sub", "Subject"]
# end_texts = ["Yours faithfully", "Yours sincerely","Yours Faithfully","Thanking you","Thanking You","Kindly take note of the same.","Thanks & Regards"]
#
# # Execute the loop 2 times
# for _ in range(1):
#     update_database_with_extracted_text(folder_path, db_file_path, excel_file_path, start_texts, end_texts)
#     delete_row_from_excel(excel_file_path, "Ramu2", 5)
#     time.sleep(10)
#     print("10 seconds have passed.")
#
# # Send Telegram alert
# bot_token = '6935326572:AAGYtturdBCopuDFqSIvz88mmBv-0oVgvE0'  # Replace with your actual bot token
# chat_id = '1178469727'  # Replace with your actual chat ID
# message = 'Step 1 still not complete wait only extraction complete'
# send_telegram_message(bot_token, chat_id, message)

# %%
#9 News extract 
#i update this 23/09/2025 bcz in excel file some time corrupt in linux so i remevode the part of code excel filedata read  see it is only data like this "News" like this data is there so mentioned this directly int the code 

import os
import pandas as pd
from PyPDF2 import PdfReader
import sqlite3
import time
import requests

# ------------------------
# Function: Extract text from PDF
# ------------------------
def extract_text_from_pdf(file_path, start_texts, end_texts, max_words=750):
    try:
        with open(file_path, 'rb') as file:
            reader = PdfReader(file)
            full_text = ""
            for page in reader.pages:
                text = page.extract_text()
                if text:
                    full_text += text

            # Find start text
            start_index = -1
            for start_text in start_texts:
                start_index = full_text.find(start_text)
                if start_index != -1:
                    break

            # Find end text
            if start_index != -1:
                end_index = -1
                for end_text in end_texts:
                    end_index = full_text.find(end_text, start_index)
                    if end_index != -1:
                        break

                if end_index != -1:
                    extracted_text = full_text[start_index:end_index + len(end_text)]
                    words = extracted_text.split()
                    if len(words) > max_words:
                        extracted_text = ' '.join(words[:max_words])
                    return extracted_text

            return full_text
    except Exception as e:
        print(f"An error occurred while processing {file_path}: {e}")
        return None


# ------------------------
# Function: Update database
# ------------------------
def update_database_with_extracted_text(folder_path, db_file_path, table_name, start_texts, end_texts):
    try:
        conn = sqlite3.connect(db_file_path)
        c = conn.cursor()

        # Check if NEWS column exists, if not add it
        c.execute(f"PRAGMA table_info({table_name})")
        columns = c.fetchall()
        column_names = [col[1] for col in columns]
        if 'NEWS' not in column_names:
            c.execute(f"ALTER TABLE {table_name} ADD COLUMN NEWS TEXT")

        # Fetch rows
        c.execute(f"SELECT * FROM {table_name}")
        rows = c.fetchall()

        for row in rows:
            if len(row) > 10:  # make sure column index 10 exists
                pdf_file_name = str(row[10])
                pdf_file_path = os.path.join(folder_path, pdf_file_name)

                if os.path.exists(pdf_file_path):
                    extracted_text = extract_text_from_pdf(pdf_file_path, start_texts, end_texts)
                    if extracted_text is not None:
                        c.execute(f"UPDATE {table_name} SET NEWS = ? WHERE LINKS = ?",
                                  (extracted_text, pdf_file_name))
                        print(f"Text extracted successfully from: {pdf_file_name}")
                else:
                    print(f"PDF file '{pdf_file_name}' not found at path: {pdf_file_path}.")

        conn.commit()
        print("Update successful")
        conn.close()
    except Exception as e:
        print(f"An error occurred while updating the database: {e}")


# ------------------------
# Function: Send Telegram message
# ------------------------
def send_telegram_message(token, chat_id, message):
    url = f"https://api.telegram.org/bot{token}/sendMessage"
    payload = {
        "chat_id": chat_id,
        "text": message
    }
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        print("Message sent successfully!")
    else:
        print(f"Failed to send message. Status code: {response.status_code}")


# ------------------------
# File paths and parameters
# ------------------------
folder_path = r"C:\Users\bomma\Desktop\Github\All download pdfs"
db_file_path = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

# ✅ Directly mention table name (no Excel needed)
table_name = "News"

start_texts = ["Sub", "Subject"]
end_texts = [
    "Yours faithfully", "Yours sincerely", "Yours Faithfully",
    "Thanking you", "Thanking You", "Kindly take note of the same.",
    "Thanks & Regards"
]

# ------------------------
# Run the process
# ------------------------
update_database_with_extracted_text(folder_path, db_file_path, table_name, start_texts, end_texts)
time.sleep(10)
print("10 seconds have passed.")
# Out:
# Text extracted successfully from: SYMPHONY_31102025231406_Con_Call_31_10_2025.pdf
# unknown widths :
# [0, IndirectObject(102, 0, 1553354481184)]
# unknown widths :
# [0, IndirectObject(106, 0, 1553354481184)]
# unknown widths :
# [0, IndirectObject(110, 0, 1553354481184)]
# unknown widths :
# [0, IndirectObject(114, 0, 1553354481184)]
# Text extracted successfully from: yashpakka_31102025231229_2510_Investor_Call_Intimation.pdf
# Text extracted successfully from: SYMPHONY_31102025230354_Letter_for_Stock_Exchange_31_10_2025.pdf
# Text extracted successfully from: GABRIEL_31102025224434_SEIntimation_Reg29_signed.pdf
# Text extracted successfully from: MARUTIASHISH_31102025224351_StxIntimation_AudioRecording_30Sep2025.pdf
# Text extracted successfully from: NACLIND_31102025224233_SEINTIMATIONPB31102025.pdf
# Text extracted successfully from: NAZARA_31102025221554_IntimationChangeinRO.pdf
# Text extracted successfully from: GODREJCP_31102025221152_SE_TDS_Cover_Letter-Signed.pdf
# Text extracted successfully from: COFORGE_31102025215806_Transcript_Intimation.pdf
# unknown widths :
# [0, IndirectObject(140, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(143, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(146, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(149, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(152, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(155, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(158, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(161, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(164, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(167, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(170, 0, 1553349101568)]
# Text extracted successfully from: VEDL_31102025215444_4VEDL_SEIntimation_ConferenceCall_RecordingLink_signed.pdf
# unknown widths :
# [0, IndirectObject(199, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(202, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(205, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(208, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(211, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(235, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(238, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(241, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(244, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(247, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(271, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(274, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(277, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(280, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(283, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(286, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(289, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(292, 0, 1553349101568)]
# unknown widths :
# [0, IndirectObject(295, 0, 1553349101568)]
# Text extracted successfully from: CLNINDIA_31102025214256_HCILBMOutcome310125SIGNED.pdf
# Text extracted successfully from: MHRIL_31102025214348_SE_Earnings_calls_outcome_Intimation_signed.pdf
# unknown widths :
# [0, IndirectObject(140, 0, 1553359211696)]
# Text extracted successfully from: SYNGENE3_31102025213827_Investorcallinitimation_November62025_Signed.pdf
# Text extracted successfully from: RELIGARE_31102025213324_RELUPDATE31102025.pdf
# unknown widths :
# [0, IndirectObject(143, 0, 1553359211696)]
# unknown widths :
# [0, IndirectObject
# Text extracted successfully from: ZAGGLE_31102025163321_EGM_Proceeding.pdf
# Text extracted successfully from: SPANDANA_31102025163306_SEOutcomeBMQ2FY26.pdf
# Text extracted successfully from: Shailyengineering_31102025163432_Reg_30_Intimation_of_loan_to_subsidiary.pdf
# Text extracted successfully from: SCHAEFFLERUSER1_31102025163302_Schaeffler_Reg30_BMOutcome_Oct312025.pdf
# Text extracted successfully from: NDTV_31102025162754_NDTV_Newspaper_Publication_311025.pdf
# Text extracted successfully from: CGCL_31102025162626_NP_Intimations.pdf
# Text extracted successfully from: INDIAMART_31102025162606_InvestorMeetDisclosure31102025.pdf
# Text extracted successfully from: Mathew_31102025162404_BSENSE031102025.pdf
# Text extracted successfully from: BPCL22_31102025162402_1stexchangerelodgments311025.pdf
# Text extracted successfully from: INDIANB_31102025162312_SE_Revision_Interest__Rate_31102025.pdf
# Text extracted successfully from: SCHAEFFLERUSER1_31102025162159_Schaeffler_Reg30_BMOutcome_Oct312025.pdf
# Text extracted successfully from: RBA_31102025161856_Finalupload.pdf
# unknown widths :
# [0, IndirectObject(70, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(74, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(78, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(82, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(86, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(90, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(94, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(98, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(102, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(106, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(110, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(114, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(118, 0, 1553350159120)]
# unknown widths :
# [0, IndirectObject(122, 0, 1553350159120)]
# Text extracted successfully from: WELCORP_31102025162005_SENEWSPAPER.pdf
# Text extracted successfully from: PFC2023_31102025161933_IntimationEDSUPERRANUATIONsigned311025.pdf
# Text extracted successfully from: STEELCAS_31102025161904_MergedQ2FY26OutcomeSigned.pdf
# Text extracted successfully from: SHARDACROP_31102025161855_NSE.pdf
# Text extracted successfully from: STEELCAS_31102025161759_MergedQ2FY26OutcomeSigned.pdf
# Text extracted successfully from: SHARDACROP_31102025161701_NSE.pdf
# Text extracted successfully from: STEELCAS_31102025161527_MergedQ2FY26OutcomeSigned.pdf
# Text extracted successfully from: POLICYBZR_31102025161300_IntimationforNewspaperPublication31102025.pdf
# Text extracted successfully from: DIXON_31102025160653_Outcome.pdf
# Text extracted successfully from: BHARTIARTL_31102025160436_Reg30DoTOct30MP_sgd.pdf
# Text extracted successfully from: ESCORTS2_31102025155711_EKL_2025_10_31_Intimation_of_Resignation_Director_Signed.pdf
# Text extracted successfully from: TATVA_31102025160510_I.pdf
# Text extracted successfully from: COALINDIA_31102025160503_ed_cs_lettersigned.pdf
# Text extracted successfully from: MARUTIASHISH_31102025144157_StxIntimation_Investor_Presentation_30_09_2025.pdf
# Text extracted successfully from: VEDL_31102025144326_VEDLSEIntimationOutcomeofBMResults31Oct2025signed.pdf
# Text extracted successfully from: IGARASHI_31102025144210_IMILSEPhySHReLodge311025SD.pdf
# An error occurred while processing C:\Users\bomma\Desktop\Github\All download pdfs\VEDL_31102025144052_VEDLSEIntimationOutcomeofBMResults31Oct2025signed.pdf: [Errno 22] Invalid argument
# Text extracted successfully from: KALPATPOWR_31102025144050_SEIntimationOutcomeOthers31102025.pdf
# Text extracted successfully from: NELCAST1_31102025144021_IntConcallAudiRecord31102025.pdf
# unknown widths :
# [0, IndirectObject(167, 0, 1553357354000)]
# unknown widths :
# [0, IndirectObject(171, 0, 1553357354000)]
# unknown widths :
# [0, IndirectObject(175, 0, 1553357354000)]
# unknown widths :
# [0, IndirectObject(179, 0, 1553357354000)]
# Multiple definitions in dictionary at byte 0x7a for key /Subtype
# Text extracted successfully from: MARUTIASHISH_31102025143752_StxIntimation_Press_Release_Financial_Results_30_09_2025.pdf
# Text extracted successfully from: KALPATPOWR_31102025143713_SEIntimationOutcomeOthers31102025.pdf
# ...
# unknown widths :
# [0, IndirectObject(44, 0, 1553353163408)]
# unknown widths :
# [0, IndirectObject(39, 0, 1553353163408)]
# unknown widths :
# [0, IndirectObject(34, 0, 1553353163408)]
# unknown widths :
# [0, IndirectObject(29, 0, 1553353163408)]
# Text extracted successfully from: truneshgujar_28102025141350_PRESENTATION.pdf
# Text extracted successfully from: esfb_28102025141245_SE__RBI_Communication_on_Scheme_of_Arrangement.pdf
# unknown widths :
# [0, IndirectObject(56, 0, 1553356607504)]
# unknown widths :
# [0, IndirectObject(51, 0, 1553356607504)]
# unknown widths :
# [0, IndirectObject(46, 0, 1553356607504)]
# unknown widths :
# [0, IndirectObject(41, 0, 1553356607504)]
# unknown widths :
# [0, IndirectObject(36, 0, 1553356607504)]
# unknown widths :
# [0, IndirectObject(31, 0, 1553356607504)]
# unknown widths :
# [0, IndirectObject(26, 0, 1553356607504)]
# Text extracted successfully from: SSKL_28102025141213_Q2resultspaperad.pdf
# Text extracted successfully from: JINDALSAW_28102025141118_Investor_Call.pdf
# Text extracted successfully from: SSKL_28102025140956_concallaudioQ2.pdf
# Text extracted successfully from: VSSL_28102025140737_ESOP_Outcome_SD.pdf
# Text extracted successfully from: truneshgujar_28102025140004_PRESS_RELEASE.pdf
# Text extracted successfully from: Verandaipo_28102025135825_REG30INVESTORPPT.pdf
# Text extracted successfully from: VSSL_28102025135606_Results_sd.pdf
# unknown widths :
# [0, IndirectObject(366, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(361, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(356, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(351, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(346, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(341, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(334, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(329, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(324, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(319, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(314, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(309, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(304, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(299, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(290, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(285, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(280, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(275, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(270, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(265, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(260, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(255, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(250, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(245, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(236, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(231, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(226, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(221, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(216, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(211, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject(206, 0, 1553576147712)]
# Text extracted successfully from: Verandaipo_28102025135357_REG30PRESS.pdf
# Text extracted successfully from: TNPL_28102025135321_319thBMNewspaper28102025_CSDSC.pdf
# unknown widths :
# [0, IndirectObject(201, 0, 1553576147712)]
# unknown widths :
# [0, IndirectObject
# unknown widths :
# [0, IndirectObject(171, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(175, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(179, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(183, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(187, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(191, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(195, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(199, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(203, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(207, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(211, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(215, 0, 1553352573440)]
# unknown widths :
# [0, IndirectObject(219, 0, 1553352573440)]
# Text extracted successfully from: HONDAPOWER_28102025105157_NewspaperAdvertisment.pdf
# Text extracted successfully from: MINDAIND1_28102025104811_Earning_Call_Q2Results.pdf
# Text extracted successfully from: DIXON_28102025104824_Intimation.pdf
# Text extracted successfully from: RATNAMANI_28102025104422_RMTLREPL28102025.pdf
# Text extracted successfully from: DIXON_28102025104506_Outcome.pdf
# unknown widths :
# [0, IndirectObject(79, 0, 1553356003120)]
# unknown widths :
# [0, IndirectObject(74, 0, 1553356003120)]
# unknown widths :
# [0, IndirectObject(69, 0, 1553356003120)]
# unknown widths :
# [0, IndirectObject(64, 0, 1553356003120)]
# Text extracted successfully from: PDSL_28102025104446_Ltr_NewspaperAdvt_28102025_signed.pdf
# Text extracted successfully from: RATEGAIN_28102025104227_RG_PR_28102025.pdf
# unknown widths :
# [0, IndirectObject(59, 0, 1553356003120)]
# unknown widths :
# [0, IndirectObject(54, 0, 1553356003120)]
# Text extracted successfully from: KPITTECH_28102025103748_Outcome28.pdf
# Text extracted successfully from: AUROPHARMA_28102025103607_LtrToSEsInvestorMeet28102025.pdf
# Text extracted successfully from: AUROPHARMA_28102025103333_LtrToSEsEarningCallDate28102025.pdf
# Text extracted successfully from: DBL_28102025103232_Final74_5_.pdf
# Text extracted successfully from: CUMMINSIND_28102025100617_SIGNEDFinalCombinedSEearningsCallNov72025.pdf
# Text extracted successfully from: NEULANDLAB_28102025091522_SignedSEIntimation_Earningscallinvite_Q2FY26.pdf
# Text extracted successfully from: HINDOILEXPCS_28102025090019_SEIntimation_ClarificationB80_28102025_signed.pdf
# Text extracted successfully from: MPHASIS_28102025082516_MLIntimation28102025.pdf
# Update successful
# 10 seconds have passed.

# %%
#10 It is column name adding
import sqlite3

# Database file path
db_file_path = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

# Column names to be added
columns_to_add = [
    "News_date TEXT",
    "Date TEXT",
    "Market TEXT",
    "Market_date TEXT",
    "Previous_close TEXT",
    "Open TEXT",
    "High TEXT",
    "Low TEXT",
    "Close TEXT",
    "High_percentage TEXT",
    "Low_percentage TEXT",
    "Open_percentage TEXT",
    "Close_percentage TEXT",
    "d1_date TEXT",
    "d1_market_date TEXT",
    "d1_previous_close TEXT",
    "d1_open TEXT",
    "d1_high TEXT",
    "d1_low TEXT",
    "d1_close TEXT",
    "d1_high_percentage TEXT",
    "d1_low_percentage TEXT",
    "d1_open_percentage TEXT",
    "d1_close_percentage TEXT",
    "d7_date TEXT",
    "d7_market_date TEXT",
    "d7_previous_close TEXT",
    "d7_open TEXT",
    "d7_high TEXT",
    "d7_low TEXT",
    "d7_close TEXT",
    "d7_high_percentage TEXT",
    "d7_low_percentage TEXT",
    "d7_open_percentage TEXT",
    "d7_close_percentage TEXT",
    "Final_market_date TEXT",
    "Filter_dates TEXT",
    "Open_time TEXT",
    "Close_time TEXT",
    "d1_open_time TEXT",
    "d1_close_time TEXT",
    "d7_open_time TEXT",
    "d7_close_time TEXT",
    "Highest_time TEXT",
    "Lowest_time TEXT"
]

try:
    # Connect to the database
    conn = sqlite3.connect(db_file_path)
    cursor = conn.cursor()

    # Add new columns to the table
    for column in columns_to_add:
        cursor.execute(f"ALTER TABLE News ADD COLUMN {column};")

    # Commit the changes
    conn.commit()
    print("Columns added successfully.")

except sqlite3.Error as e:
    print("Error:", e)

finally:
    # Close the connection
    if conn:
        conn.close()
# Out:
# Columns added successfully.

# %%
#11 Reciept Data copy
import sqlite3

# Database file path
db_file = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

try:
    # Connect to the database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()

    # Select data from the 'RECEIPT' column in the 'News' table
    cursor.execute("SELECT RECEIPT FROM News")

    # Fetch all rows
    rows = cursor.fetchall()

    # Iterate through the rows
    for row in rows:
        # Assuming the data in 'RECEIPT' is a string representing a date
        receipt_date = row[0]

        # Update the 'News_date' column with the value from 'RECEIPT'
        cursor.execute("UPDATE News SET News_date = ? WHERE RECEIPT = ?", (receipt_date, receipt_date))

    # Commit the changes
    conn.commit()
    print("Data updated successfully.")

except sqlite3.Error as e:
    print("Error:", e)

finally:
    # Close the connection
    conn.close()
# Out:
# Data updated successfully.

# %%
#12 Date extract
import sqlite3
from datetime import datetime

# Path to your SQLite database file
db_file_path = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

# Function to extract date from datetime string
def extract_date(datetime_str):
    try:
        # Parse the datetime string
        datetime_obj = datetime.strptime(datetime_str, '%Y-%m-%d %H:%M:%S')
        
        # Extract the date portion
        date_str = datetime_obj.strftime('%Y-%m-%d')
        
        return date_str
        
    except ValueError as e:
        print(f"Error extracting date from datetime string: {e}")
        return None

# Function to update the "Date" column in the "News" table
def update_date_column_in_news_table():
    try:
        # Connect to the database
        conn = sqlite3.connect(db_file_path)
        cursor = conn.cursor()
        
        # Check if the "News_date" column exists in the "News" table
        cursor.execute("PRAGMA table_info('News')")
        columns = cursor.fetchall()
        if any('News_date' in column for column in columns):
            # Fetch all rows from the "News" table
            cursor.execute("SELECT rowid, News_date FROM News")
            rows = cursor.fetchall()
            
            # Update each row with the extracted date
            for row in rows:
                row_id, news_date = row
                date = extract_date(news_date)
                if date:
                    # Update the "Date" column with the extracted date
                    cursor.execute("UPDATE News SET Date = ? WHERE rowid = ?", (date, row_id))
        else:
            print("The 'News' table does not have a 'News_date' column. Skipping...")
        
        # Commit the changes
        conn.commit()
        print("Date extracted and added to the 'Date' column in the 'News' table successfully.")
        
    except sqlite3.Error as e:
        print(f"Error updating 'Date' column in the 'News' table: {e}")
        
    finally:
        # Close the connection
        if conn:
            conn.close()

# Main function
def main():
    # Update the "Date" column in the "News" table
    update_date_column_in_news_table()

# Call the main function
if __name__ == "__main__":
    main()
# Out:
# Date extracted and added to the 'Date' column in the 'News' table successfully.

# %%
#13 ofter and before market update
import sqlite3
from datetime import datetime

# Database file path
db_file = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

def update_market_column(db_file):
    # Connect to the database
    conn = sqlite3.connect(db_file)
    cursor = conn.cursor()
    
    # Function to add Market column if not exists
    def add_market_column_if_not_exists(cursor):
        cursor.execute("PRAGMA table_info(News);")
        columns = cursor.fetchall()
        column_names = [column[1] for column in columns]
        if 'Market' not in column_names:
            cursor.execute("ALTER TABLE News ADD COLUMN Market TEXT;")
            print("Added 'Market' column to table 'News'.")
    
    try:
        # Add Market column if not exists
        add_market_column_if_not_exists(cursor)
        
        # Retrieve data from the table
        cursor.execute("SELECT rowid, News_date FROM News;")
        rows = cursor.fetchall()
        
        # Update 'Market' column based on time conditions
        for row in rows:
            rowid = row[0]
            news_date_str = row[1]
            news_date = datetime.strptime(news_date_str, "%Y-%m-%d %H:%M:%S")
            news_time = news_date.time()
            market = ""
            if datetime.strptime("15:30:00", "%H:%M:%S").time() <= news_time <= datetime.strptime("23:59:00", "%H:%M:%S").time():
                market = "Ofter"
            elif datetime.strptime("09:15:00", "%H:%M:%S").time() <= news_time <= datetime.strptime("15:30:00", "%H:%M:%S").time():
                market = "Within"
            else:
                market = "Before"
            
            # Update 'Market' column for the row
            cursor.execute("UPDATE News SET Market = ? WHERE rowid = ?;", (market, rowid))
    except Exception as e:
        print(f"Error updating table 'News': {str(e)}")
    
    # Commit changes and close connection
    conn.commit()
    conn.close()

# Call the function to update the 'Market' column for the 'News' table
update_market_column(db_file)

# %%
#14 from database to csv empty files create
import sqlite3
import csv
import os

# Database file path
db_file_path = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"

# Folder path to save CSV files
csv_folder_path = r"C:\Users\bomma\Desktop\Github\Mine Final CSVs"

# Connect to the database
conn = sqlite3.connect(db_file_path)
cursor = conn.cursor()

# Get symbols from the database
cursor.execute("SELECT DISTINCT SYMBOL FROM News")
symbols = cursor.fetchall()

# Create CSV files for each symbol
for symbol in symbols:
    symbol_name = symbol[0]
    csv_file_path = os.path.join(csv_folder_path, f"{symbol_name}.csv")
    
    # Create an empty CSV file
    with open(csv_file_path, "w", newline='') as csvfile:
        csv_writer = csv.writer(csvfile)
        # Write headers if needed
        # csv_writer.writerow(["Column1", "Column2", ...])
        
# Close the database connection
conn.close()

print("CSV files created successfully.")
# Out:
# CSV files created successfully.

# %% [markdown]
# #15 csv file data from database
# import sqlite3
# import csv
# import os
#
# # Define paths
# database_path = r"C:\Users\bomma\Desktop\Rough Create\Single day Reports\Database\News Analysis.db"
# csv_folder_path = r"C:\Users\bomma\Desktop\Rough Create\Single day Reports\CSV file"
#
# # Create CSV folder if it doesn't exist
# os.makedirs(csv_folder_path, exist_ok=True)
#
# # Connect to the database
# conn = sqlite3.connect(database_path)
# cursor = conn.cursor()
#
# # Select data from the "News" table
# cursor.execute("SELECT * FROM News")
# rows = cursor.fetchall()
#
# # Define CSV file path
# csv_file_path = os.path.join(csv_folder_path, "news_data.csv")
#
# # Write data to CSV file
# with open(csv_file_path, 'w', newline='') as csvfile:
#     csv_writer = csv.writer(csvfile)
#     # Write header
#     csv_writer.writerow([i[0] for i in cursor.description])
#     # Write rows
#     csv_writer.writerows(rows)
#
# # Close database connection
# conn.close()
#
# print("CSV file has been created successfully at:", csv_file_path)

# %%
#15 csv file data from database
import sqlite3
import csv
import os

# Define paths
database_path = r"C:\Users\bomma\Desktop\Github\Database\News Analysis.db"
csv_folder_path = r"C:\Users\bomma\Desktop\Github\CSV file"

# Create CSV folder if it doesn't exist
os.makedirs(csv_folder_path, exist_ok=True)

# Connect to the database
conn = sqlite3.connect(database_path)
cursor = conn.cursor()

# Select data from the "News" table
cursor.execute("SELECT * FROM News")

# Define CSV file path
csv_file_path = os.path.join(csv_folder_path, "news_data.csv")

# Write data to CSV file with UTF-8 encoding
with open(csv_file_path, 'w', newline='', encoding='utf-8') as csvfile:
    csv_writer = csv.writer(csvfile)
    
    # Write header only once
    csv_writer.writerow([i[0] for i in cursor.description])
    
    # Write rows in chunks for memory efficiency
    while True:
        rows = cursor.fetchmany(1000)  # Fetch 1000 rows at a time
        if not rows:
            break
        csv_writer.writerows(rows)

# Close database connection
conn.close()

print("CSV file has been created successfully at:", csv_file_path)
# Out:
# CSV file has been created successfully at: C:\Users\bomma\Desktop\Github\CSV file\news_data.csv

# %%
#16 data add from Raw Csv file to each csv single file
import os
import pandas as pd

# File paths
source_csv_path = r'C:\Users\bomma\Desktop\Github\CSV file\news_data.csv'
stocks_folder_path = r'C:\Users\bomma\Desktop\Github\Mine Final CSVs'

# Read the source CSV file
source_df = pd.read_csv(source_csv_path)

# Get unique symbols from the 'SYMBOL' column
symbols = source_df['SYMBOL'].unique()

# Iterate over each symbol
for symbol in symbols:
    # Check if the corresponding CSV file exists for the symbol
    symbol_csv_path = os.path.join(stocks_folder_path, f'{symbol}.csv')
    if os.path.exists(symbol_csv_path):
        # Filter rows with the current symbol
        symbol_data = source_df[source_df['SYMBOL'] == symbol]
        
        # Append data to the symbol's CSV file
        if not os.path.getsize(symbol_csv_path):  # Check if the file is empty
            symbol_data.to_csv(symbol_csv_path, mode='a', header=True, index=False)  # Write header if file is empty
        else:
            symbol_data.to_csv(symbol_csv_path, mode='a', header=False, index=False)  # Append data without header
    else:
        print(f"CSV file not found for symbol '{symbol}'")

# %%
#17 empty database create
import sqlite3
import os

# Define the folder path
folder_path = r"C:\Users\bomma\Desktop\Github\News Now"

# Check if the folder exists, if not, create it
if not os.path.exists(folder_path):
    os.makedirs(folder_path)

# Construct the full file path for the SQLite database
db_file_path = os.path.join(folder_path, 'Final Analysis.db')

# Create an empty SQLite database file
with sqlite3.connect(db_file_path) as conn:
    print("Database file created successfully at:", db_file_path)

# Close the connection
conn.close()
# Out:
# Database file created successfully at: C:\Users\bomma\Desktop\Github\News Now\Final Analysis.db

# %% [markdown]
# #18 csv data save in database
# import os
# import pandas as pd
# import sqlite3
#
# # Folder path containing CSV files
# csv_folder = r"C:\Users\bomma\Desktop\Github\Mine Final CSVs"
#
# # Database file path
# db_file = r'C:\Users\bomma\Desktop\Github\News Now\Final Analysis.db'
#
# # Function to create database table from CSV file
# def create_table_from_csv(csv_file, cursor):
#     table_name = os.path.splitext(os.path.basename(csv_file))[0]  # Extract table name from CSV file name
#     df = pd.read_csv(csv_file)  # Read CSV file into DataFrame
#     try:
#         # Replace any spaces in column names with underscores
#         df.columns = df.columns.str.replace(' ', '_')
#     except ValueError:
#         pass  # Ignore length mismatch error
#     df.to_sql(table_name, conn, if_exists='replace', index=False)  # Write DataFrame to SQLite database as a table
#
# # Connect to SQLite database
# conn = sqlite3.connect(db_file)
# cursor = conn.cursor()
#
# # Iterate over CSV files in the folder
# for file_name in os.listdir(csv_folder):
#     if file_name.endswith('.csv'):
#         csv_file_path = os.path.join(csv_folder, file_name)
#         create_table_from_csv(csv_file_path, cursor)
#
# # Commit changes and close connection
# conn.commit()
# conn.close()
#
# print("Database successfully created from CSV files.")

# %%
#Updated version 18 csv data save in database  (Python int too large to convert to SQLite INTEGER some tables notr taking data it shows error so ) 
import os
import pandas as pd
import sqlite3
import traceback

# Folder path containing CSV files
csv_folder = r"C:\Users\bomma\Desktop\Github\Mine Final CSVs"

# Database file path
db_file = r'C:\Users\bomma\Desktop\Github\News Now\Final Analysis.db'

# Function to create database table from CSV file
def create_table_from_csv(csv_file, conn):
    table_name = os.path.splitext(os.path.basename(csv_file))[0]  # Extract table name from CSV file name
    try:
        df = pd.read_csv(csv_file)  # Read CSV file into DataFrame
        
        # Replace spaces in column names with underscores
        df.columns = df.columns.str.replace(' ', '_')
        
        # Check for large integers and convert them to strings if needed
        for column in df.select_dtypes(include=['int']).columns:
            if df[column].max() > 9223372036854775807:  # SQLite INTEGER max value
                df[column] = df[column].astype(str)  # Convert to string
        
        # Write DataFrame to SQLite database as a table
        df.to_sql(table_name, conn, if_exists='replace', index=False)
        print(f"Table '{table_name}' created successfully.")
    except Exception as e:
        # Print the error and the file causing it
        print(f"Error processing file: {csv_file}")
        print("Error details:")
        traceback.print_exc()

# Connect to SQLite database
conn = sqlite3.connect(db_file)

# Iterate over CSV files in the folder
for file_name in os.listdir(csv_folder):
    if file_name.endswith('.csv'):
        csv_file_path = os.path.join(csv_folder, file_name)
        print(f"Processing file: {csv_file_path}")
        create_table_from_csv(csv_file_path, conn)

# Commit changes and close connection
conn.commit()
conn.close()

print("Database creation process completed.")
# Out:
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AARTIDRUGS.csv
# Table 'AARTIDRUGS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AARTIIND.csv
# Table 'AARTIIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AAVAS.csv
# Table 'AAVAS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ABB.csv
# Table 'ABB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ABCAPITAL.csv
# Table 'ABCAPITAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ABFRL.csv
# Table 'ABFRL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ACC.csv
# Table 'ACC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ACE.csv
# Table 'ACE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ACLGATI.csv
# Table 'ACLGATI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ADANIENSOL.csv
# Table 'ADANIENSOL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ADANIGREEN.csv
# Table 'ADANIGREEN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ADANIPORTS.csv
# Table 'ADANIPORTS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ADFFOODS.csv
# Table 'ADFFOODS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AEROFLEX.csv
# Table 'AEROFLEX' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AFFLE.csv
# Table 'AFFLE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AGI.csv
# Table 'AGI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AJMERA.csv
# Table 'AJMERA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AKZOINDIA.csv
# Table 'AKZOINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ALICON.csv
# Table 'ALICON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ALKEM.csv
# Table 'ALKEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ALKYLAMINE.csv
# Table 'ALKYLAMINE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ALLCARGO.csv
# Table 'ALLCARGO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AMBUJACEM.csv
# Table 'AMBUJACEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ANANDRATHI.csv
# Table 'ANANDRATHI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ANDHRAPAP.csv
# Table 'ANDHRAPAP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APARINDS.csv
# Table 'APARINDS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APCOTEXIND.csv
# Table 'APCOTEXIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APLAPOLLO.csv
# Table 'APLAPOLLO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APLLTD.csv
# Table 'APLLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APOLLOHOSP.csv
# Table 'APOLLOHOSP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APOLLOPIPE.csv
# Table 'APOLLOPIPE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APOLLOTYRE.csv
# Table 'APOLLOTYRE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\APTUS.csv
# Table 'APTUS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ARVIND.csv
# Table 'ARVIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ARVINDFASN.csv
# Table 'ARVINDFASN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ARVSMART.csv
# Table 'ARVSMART' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ASHIANA.csv
# Table 'ASHIANA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ASHOKA.csv
# Table 'ASHOKA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ASIANTILES.csv
# Table 'ASIANTILES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ASTEC.csv
# Table 'ASTEC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ASTRAL.csv
# Table 'ASTRAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ASTRAMICRO.csv
# Table 'ASTRAMICRO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ATGL.csv
# Table 'ATGL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ATUL.csv
# Table 'ATUL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AUBANK.csv
# Table 'AUBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AUROPHARMA.csv
# Table 'AUROPHARMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AUTOAXLES.csv
# Table 'AUTOAXLES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AVANTIFEED.csv
# Table 'AVANTIFEED' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AWHCL.csv
# Table 'AWHCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AXISBANK.csv
# Table 'AXISBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\AXISCADES.csv
# Table 'AXISCADES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BAJAJELEC.csv
# Table 'BAJAJELEC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BALKRISIND.csv
# Table 'BALKRISIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BALMLAWRIE.csv
# Table 'BALMLAWRIE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BANDHANBNK.csv
# Table 'BANDHANBNK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BANKBARODA.csv
# Table 'BANKBARODA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BANKINDIA.csv
# Table 'BANKINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BATAINDIA.csv
# Table 'BATAINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BBL.csv
# Table 'BBL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BCLIND.csv
# Table 'BCLIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BDL.csv
# Table 'BDL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BEL.csv
# Table 'BEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BEML.csv
# Table 'BEML' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BEPL.csv
# Table 'BEPL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BERGEPAINT.csv
# Table 'BERGEPAINT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BFUTILITIE.csv
# Table 'BFUTILITIE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BGRENERGY.csv
# Table 'BGRENERGY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BHAGCHEM.csv
# Table 'BHAGCHEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BHARATRAS.csv
# Table 'BHARATRAS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BHARTIARTL.csv
# Table 'BHARTIARTL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BHEL.csv
# Table 'BHEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BIOCON.csv
# Table 'BIOCON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BLS.csv
# Table 'BLS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BLUEDART.csv
# Table 'BLUEDART' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BLUESTARCO.csv
# Table 'BLUESTARCO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BORORENEW.csv
# Table 'BORORENEW' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BOSCHLTD.csv
# Table 'BOSCHLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BPCL.csv
# Table 'BPCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BRIGADE.csv
# Table 'BRIGADE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BRITANNIA.csv
# Table 'BRITANNIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\BSOFT.csv
# Table 'BSOFT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CAMLINFINE.csv
# Table 'CAMLINFINE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CAMS.csv
# Table 'CAMS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CANBK.csv
# Table 'CANBK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CANFINHOME.csv
# Table 'CANFINHOME' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CANTABIL.csv
# Table 'CANTABIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CAPLIPOINT.csv
# Table 'CAPLIPOINT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CARBORUNIV.csv
# Table 'CARBORUNIV' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CARTRADE.csv
# Table 'CARTRADE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CARYSIL.csv
# Table 'CARYSIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CASTROLIND.csv
# Table 'CASTROLIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CCL.csv
# Table 'CCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CDSL.csv
# Table 'CDSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CENTRALBK.csv
# Table 'CENTRALBK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CENTRUM.csv
# Table 'CENTRUM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CENTURYPLY.csv
# Table 'CENTURYPLY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CERA.csv
# Table 'CERA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CESC.csv
# Table 'CESC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CGCL.csv
# Table 'CGCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CGPOWER.csv
# Table 'CGPOWER' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CHALET.csv
# Table 'CHALET' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CHAMBLFERT.csv
# Table 'CHAMBLFERT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CHENNPETRO.csv
# Table 'CHENNPETRO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CHOLAFIN.csv
# Table 'CHOLAFIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CIEINDIA.csv
# Table 'CIEINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CIPLA.csv
# Table 'CIPLA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CMSINFO.csv
# Table 'CMSINFO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\COALINDIA.csv
# Table 'COALINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\COFORGE.csv
# Table 'COFORGE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\COLPAL.csv
# Table 'COLPAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CONCOR.csv
# Table 'CONCOR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\COROMANDEL.csv
# Table 'COROMANDEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CRAFTSMAN.csv
# Table 'CRAFTSMAN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CREDITACC.csv
# Table 'CREDITACC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CROMPTON.csv
# Table 'CROMPTON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CSBBANK.csv
# Table 'CSBBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CUB.csv
# Table 'CUB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CUMMINSIND.csv
# Table 'CUMMINSIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\CYIENTDLM.csv
# Table 'CYIENTDLM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DABUR.csv
# Table 'DABUR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DATAMATICS.csv
# Table 'DATAMATICS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DBL.csv
# Table 'DBL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DCAL.csv
# Table 'DCAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DCBBANK.csv
# Table 'DCBBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DCMSHRIRAM.csv
# Table 'DCMSHRIRAM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DCW.csv
# Table 'DCW' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DEEPAKFERT.csv
# Table 'DEEPAKFERT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DEEPINDS.csv
# Table 'DEEPINDS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DELHIVERY.csv
# Table 'DELHIVERY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DEN.csv
# Table 'DEN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DENORA.csv
# Table 'DENORA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DEVYANI.csv
# Table 'DEVYANI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DHAMPURSUG.csv
# Table 'DHAMPURSUG' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DHANUKA.csv
# Table 'DHANUKA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DIVISLAB.csv
# Table 'DIVISLAB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DIXON.csv
# Table 'DIXON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DLF.csv
# Table 'DLF' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DMART.csv
# Table 'DMART' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DRREDDY.csv
# Table 'DRREDDY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\DWARKESH.csv
# Table 'DWARKESH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EASEMYTRIP.csv
# Table 'EASEMYTRIP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ECLERX.csv
# Table 'ECLERX' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EIDPARRY.csv
# Table 'EIDPARRY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EKC.csv
# Table 'EKC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EMAMILTD.csv
# Table 'EMAMILTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ENGINERSIN.csv
# Table 'ENGINERSIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EQUITASBNK.csv
# Table 'EQUITASBNK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ESAFSFB.csv
# Table 'ESAFSFB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ESCORTS.csv
# Table 'ESCORTS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EVEREADY.csv
# Table 'EVEREADY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EVERESTIND.csv
# Table 'EVERESTIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\EXIDEIND.csv
# Table 'EXIDEIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FACT.csv
# Table 'FACT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FEDERALBNK.csv
# Table 'FEDERALBNK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FEDFINA.csv
# Table 'FEDFINA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FILATEX.csv
# Table 'FILATEX' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FINOPB.csv
# Table 'FINOPB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FINPIPE.csv
# Table 'FINPIPE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FIVESTAR.csv
# Table 'FIVESTAR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FOODSIN.csv
# Table 'FOODSIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FSL.csv
# Table 'FSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\FUSION.csv
# Table 'FUSION' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GABRIEL.csv
# Table 'GABRIEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GAIL.csv
# Table 'GAIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GARFIBRES.csv
# Table 'GARFIBRES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GATEWAY.csv
# Table 'GATEWAY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GEOJITFSL.csv
# Table 'GEOJITFSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GESHIP.csv
# Table 'GESHIP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GHCL.csv
# Table 'GHCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GICHSGFIN.csv
# Table 'GICHSGFIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GILLETTE.csv
# Table 'GILLETTE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GLAND.csv
# Table 'GLAND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GLAXO.csv
# Table 'GLAXO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GMMPFAUDLR.csv
# Table 'GMMPFAUDLR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GNFC.csv
# Table 'GNFC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GOCOLORS.csv
# Table 'GOCOLORS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GODREJCP.csv
# Table 'GODREJCP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GOLDIAM.csv
# Table 'GOLDIAM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GPIL.csv
# Table 'GPIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GPPL.csv
# Table 'GPPL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GRANULES.csv
# Table 'GRANULES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GRASIM.csv
# Table 'GRASIM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GRAVITA.csv
# Table 'GRAVITA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GREAVESCOT.csv
# Table 'GREAVESCOT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GREENPLY.csv
# Table 'GREENPLY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GRINDWELL.csv
# Table 'GRINDWELL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GSFC.csv
# Table 'GSFC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\GULFOILLUB.csv
# Table 'GULFOILLUB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HAL.csv
# Table 'HAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HAPPSTMNDS.csv
# Table 'HAPPSTMNDS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HARSHA.csv
# Table 'HARSHA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HAVELLS.csv
# Table 'HAVELLS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HCLTECH.csv
# Table 'HCLTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HDFCAMC.csv
# Table 'HDFCAMC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HDFCBANK.csv
# Table 'HDFCBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HDFCLIFE.csv
# Table 'HDFCLIFE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HEIDELBERG.csv
# Table 'HEIDELBERG' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HEMIPROP.csv
# Table 'HEMIPROP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HERITGFOOD.csv
# Table 'HERITGFOOD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HEROMOTOCO.csv
# Table 'HEROMOTOCO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HEUBACHIND.csv
# Table 'HEUBACHIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HFCL.csv
# Table 'HFCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HGINFRA.csv
# Table 'HGINFRA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HGS.csv
# Table 'HGS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HIKAL.csv
# Table 'HIKAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HINDALCO.csv
# Table 'HINDALCO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HINDOILEXP.csv
# Table 'HINDOILEXP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HINDPETRO.csv
# Table 'HINDPETRO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HINDUNILVR.csv
# Table 'HINDUNILVR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HINDZINC.csv
# Table 'HINDZINC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HOMEFIRST.csv
# Table 'HOMEFIRST' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HONASA.csv
# Table 'HONASA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HONDAPOWER.csv
# Table 'HONDAPOWER' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\HUHTAMAKI.csv
# Table 'HUHTAMAKI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ICICIBANK.csv
# Table 'ICICIBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ICICIGI.csv
# Table 'ICICIGI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ICICIPRULI.csv
# Table 'ICICIPRULI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ICRA.csv
# Table 'ICRA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IDEA.csv
# Table 'IDEA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IDEAFORGE.csv
# Table 'IDEAFORGE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IEX.csv
# Table 'IEX' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IFBIND.csv
# Table 'IFBIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IGARASHI.csv
# Table 'IGARASHI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IGPL.csv
# Table 'IGPL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IIFL.csv
# Table 'IIFL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IMPAL.csv
# Table 'IMPAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INDIACEM.csv
# Table 'INDIACEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INDIAMART.csv
# Table 'INDIAMART' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INDIANB.csv
# Table 'INDIANB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INDOCO.csv
# Table 'INDOCO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INDUSINDBK.csv
# Table 'INDUSINDBK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INDUSTOWER.csv
# Table 'INDUSTOWER' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INFIBEAM.csv
# Table 'INFIBEAM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INFY.csv
# Table 'INFY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INGERRAND.csv
# Table 'INGERRAND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\INTELLECT.csv
# Table 'INTELLECT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IOC.csv
# Table 'IOC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IRCON.csv
# Table 'IRCON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\IRCTC.csv
# Table 'IRCTC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ISGEC.csv
# Table 'ISGEC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ITC.csv
# Table 'ITC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JAGSNPHARM.csv
# Table 'JAGSNPHARM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JBCHEPHARM.csv
# Table 'JBCHEPHARM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JBMA.csv
# Table 'JBMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JINDALSAW.csv
# Table 'JINDALSAW' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JINDALSTEL.csv
# Table 'JINDALSTEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JINDRILL.csv
# Table 'JINDRILL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JISLJALEQS.csv
# Table 'JISLJALEQS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JKIL.csv
# Table 'JKIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JKLAKSHMI.csv
# Table 'JKLAKSHMI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JKTYRE.csv
# Table 'JKTYRE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JSL.csv
# Table 'JSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JSWENERGY.csv
# Table 'JSWENERGY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JSWSTEEL.csv
# Table 'JSWSTEEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JUBLFOOD.csv
# Table 'JUBLFOOD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JUBLINGREA.csv
# Table 'JUBLINGREA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\JUBLPHARMA.csv
# Table 'JUBLPHARMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KALAMANDIR.csv
# Table 'KALAMANDIR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KARURVYSYA.csv
# Table 'KARURVYSYA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KAYNES.csv
# Table 'KAYNES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KCP.csv
# Table 'KCP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KDDL.csv
# Table 'KDDL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KELLTONTEC.csv
# Table 'KELLTONTEC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KFINTECH.csv
# Table 'KFINTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KICL.csv
# Table 'KICL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KIMS.csv
# Table 'KIMS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KIRLOSBROS.csv
# Table 'KIRLOSBROS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KIRLOSENG.csv
# Table 'KIRLOSENG' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KIRLPNU.csv
# Table 'KIRLPNU' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KOLTEPATIL.csv
# Table 'KOLTEPATIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KOTAKBANK.csv
# Table 'KOTAKBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KPIL.csv
# Table 'KPIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KPITTECH.csv
# Table 'KPITTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KRBL.csv
# Table 'KRBL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KRSNAA.csv
# Table 'KRSNAA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KSCL.csv
# Table 'KSCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KSOLVES.csv
# Table 'KSOLVES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KTKBANK.csv
# Table 'KTKBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\KUANTUM.csv
# Table 'KUANTUM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LALPATHLAB.csv
# Table 'LALPATHLAB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LAURUSLABS.csv
# Table 'LAURUSLABS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LEMONTREE.csv
# Table 'LEMONTREE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LGBBROSLTD.csv
# Table 'LGBBROSLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LICHSGFIN.csv
# Table 'LICHSGFIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LICI.csv
# Table 'LICI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LINCOLN.csv
# Table 'LINCOLN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LODHA.csv
# Table 'LODHA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LT.csv
# Table 'LT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LTFOODS.csv
# Table 'LTFOODS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LTIM.csv
# Table 'LTIM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LTTS.csv
# Table 'LTTS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LUMAXTECH.csv
# Table 'LUMAXTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LUPIN.csv
# Table 'LUPIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\LXCHEM.csv
# Table 'LXCHEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAHABANK.csv
# Table 'MAHABANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAHLIFE.csv
# Table 'MAHLIFE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAHLOG.csv
# Table 'MAHLOG' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAHSEAMLES.csv
# Table 'MAHSEAMLES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MANAPPURAM.csv
# Table 'MANAPPURAM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MANYAVAR.csv
# Table 'MANYAVAR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAPMYINDIA.csv
# Table 'MAPMYINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MARICO.csv
# Table 'MARICO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MARKSANS.csv
# Table 'MARKSANS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MARUTI.csv
# Table 'MARUTI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MASFIN.csv
# Table 'MASFIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MASTEK.csv
# Table 'MASTEK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAXESTATES.csv
# Table 'MAXESTATES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAYURUNIQ.csv
# Table 'MAYURUNIQ' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MAZDOCK.csv
# Table 'MAZDOCK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MEDANTA.csv
# Table 'MEDANTA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MEDPLUS.csv
# Table 'MEDPLUS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\METROBRAND.csv
# Table 'METROBRAND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\METROPOLIS.csv
# Table 'METROPOLIS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MFSL.csv
# Table 'MFSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MGL.csv
# Table 'MGL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MHRIL.csv
# Table 'MHRIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MINDACORP.csv
# Table 'MINDACORP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MINDTECK.csv
# Table 'MINDTECK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MOLDTKPAC.csv
# Table 'MOLDTKPAC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MOTHERSON.csv
# Table 'MOTHERSON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MOTILALOFS.csv
# Table 'MOTILALOFS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MPHASIS.csv
# Table 'MPHASIS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MPSLTD.csv
# Table 'MPSLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MSTCLTD.csv
# Table 'MSTCLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\MTARTECH.csv
# Table 'MTARTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NACLIND.csv
# Table 'NACLIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NATCOPHARM.csv
# Table 'NATCOPHARM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NAUKRI.csv
# Table 'NAUKRI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NAVINFLUOR.csv
# Table 'NAVINFLUOR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NAZARA.csv
# Table 'NAZARA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NCC.csv
# Table 'NCC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NDTV.csv
# Table 'NDTV' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NELCAST.csv
# Table 'NELCAST' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NESCO.csv
# Table 'NESCO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NEULANDLAB.csv
# Table 'NEULANDLAB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NFL.csv
# Table 'NFL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NH.csv
# Table 'NH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NHPC.csv
# Table 'NHPC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NIACL.csv
# Table 'NIACL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NIITLTD.csv
# Table 'NIITLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NIITMTS.csv
# Table 'NIITMTS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NITINSPIN.csv
# Table 'NITINSPIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NLCINDIA.csv
# Table 'NLCINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NMDC.csv
# Table 'NMDC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NOCIL.csv
# Table 'NOCIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NRBBEARING.csv
# Table 'NRBBEARING' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NSLNISP.csv
# Table 'NSLNISP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NTPC.csv
# Table 'NTPC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\NYKAA.csv
# Table 'NYKAA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\OBEROIRLTY.csv
# Table 'OBEROIRLTY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\OFSS.csv
# Table 'OFSS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\OIL.csv
# Table 'OIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ONGC.csv
# Table 'ONGC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ONMOBILE.csv
# Table 'ONMOBILE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\OPTIEMUS.csv
# Table 'OPTIEMUS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ORCHPHARMA.csv
# Table 'ORCHPHARMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ORIENTPPR.csv
# Table 'ORIENTPPR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ORISSAMINE.csv
# Table 'ORISSAMINE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PAISALO.csv
# Table 'PAISALO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PAKKA.csv
# Table 'PAKKA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PARADEEP.csv
# Table 'PARADEEP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PATANJALI.csv
# Table 'PATANJALI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PDSL.csv
# Table 'PDSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PERSISTENT.csv
# Table 'PERSISTENT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PFC.csv
# Table 'PFC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PGEL.csv
# Table 'PGEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PGHH.csv
# Table 'PGHH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PHOENIXLTD.csv
# Table 'PHOENIXLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PIDILITIND.csv
# Table 'PIDILITIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PILANIINVS.csv
# Table 'PILANIINVS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PITTIENG.csv
# Table 'PITTIENG' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PNB.csv
# Table 'PNB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PNBHOUSING.csv
# Table 'PNBHOUSING' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PNCINFRA.csv
# Table 'PNCINFRA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\POLICYBZR.csv
# Table 'POLICYBZR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\POLYCAB.csv
# Table 'POLYCAB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\POONAWALLA.csv
# Table 'POONAWALLA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\POWERGRID.csv
# Table 'POWERGRID' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PRAJIND.csv
# Table 'PRAJIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PRECWIRE.csv
# Table 'PRECWIRE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PREMEXPLN.csv
# Table 'PREMEXPLN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PRIVISCL.csv
# Table 'PRIVISCL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PRSMJOHNSN.csv
# Table 'PRSMJOHNSN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PRUDENT.csv
# Table 'PRUDENT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PSPPROJECT.csv
# Table 'PSPPROJECT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PURVA.csv
# Table 'PURVA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\PYRAMID.csv
# Table 'PYRAMID' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\QUESS.csv
# Table 'QUESS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RADICO.csv
# Table 'RADICO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RAILTEL.csv
# Table 'RAILTEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RAJESHEXPO.csv
# Table 'RAJESHEXPO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RAJRATAN.csv
# Table 'RAJRATAN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RALLIS.csv
# Table 'RALLIS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RAMKY.csv
# Table 'RAMKY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RATEGAIN.csv
# Table 'RATEGAIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RATNAMANI.csv
# Table 'RATNAMANI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RAYMOND.csv
# Table 'RAYMOND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RBA.csv
# Table 'RBA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RBLBANK.csv
# Table 'RBLBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RECLTD.csv
# Table 'RECLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\REDINGTON.csv
# Table 'REDINGTON' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\REDTAPE.csv
# Table 'REDTAPE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RELIANCE.csv
# Table 'RELIANCE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RELIGARE.csv
# Table 'RELIGARE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RELINFRA.csv
# Table 'RELINFRA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\REPCOHOME.csv
# Table 'REPCOHOME' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\REPRO.csv
# Table 'REPRO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RESPONIND.csv
# Table 'RESPONIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RITES.csv
# Table 'RITES' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RKFORGE.csv
# Table 'RKFORGE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ROUTE.csv
# Table 'ROUTE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RRKABEL.csv
# Table 'RRKABEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RSYSTEMS.csv
# Table 'RSYSTEMS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\RUPA.csv
# Table 'RUPA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SADHNANIQ.csv
# Table 'SADHNANIQ' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SAGCEM.csv
# Table 'SAGCEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SAIL.csv
# Table 'SAIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SAMHI.csv
# Table 'SAMHI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SANDHAR.csv
# Table 'SANDHAR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SANOFI.csv
# Table 'SANOFI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SAREGAMA.csv
# Table 'SAREGAMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SASKEN.csv
# Table 'SASKEN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SATIN.csv
# Table 'SATIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SBFC.csv
# Table 'SBFC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SBICARD.csv
# Table 'SBICARD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SBILIFE.csv
# Table 'SBILIFE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SBIN.csv
# Table 'SBIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SCHAEFFLER.csv
# Table 'SCHAEFFLER' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SESHAPAPER.csv
# Table 'SESHAPAPER' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SFL.csv
# Table 'SFL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHAILY.csv
# Table 'SHAILY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHALBY.csv
# Table 'SHALBY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHARDACROP.csv
# Table 'SHARDACROP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHARDAMOTR.csv
# Table 'SHARDAMOTR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHAREINDIA.csv
# Table 'SHAREINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHREECEM.csv
# Table 'SHREECEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHRIRAMFIN.csv
# Table 'SHRIRAMFIN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHRIRAMPPS.csv
# Table 'SHRIRAMPPS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SHYAMMETL.csv
# Table 'SHYAMMETL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SIGACHI.csv
# Table 'SIGACHI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SIGNATURE.csv
# Table 'SIGNATURE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SIYSIL.csv
# Table 'SIYSIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SKFINDIA.csv
# Table 'SKFINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SKIPPER.csv
# Table 'SKIPPER' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SMCGLOBAL.csv
# Table 'SMCGLOBAL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SNOWMAN.csv
# Table 'SNOWMAN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SOLARA.csv
# Table 'SOLARA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SOMANYCERA.csv
# Table 'SOMANYCERA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SONACOMS.csv
# Table 'SONACOMS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SONATSOFTW.csv
# Table 'SONATSOFTW' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SOUTHBANK.csv
# Table 'SOUTHBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SPANDANA.csv
# Table 'SPANDANA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SPLPETRO.csv
# Table 'SPLPETRO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SRF.csv
# Table 'SRF' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STAR.csv
# Table 'STAR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STARCEMENT.csv
# Table 'STARCEMENT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STARHEALTH.csv
# Table 'STARHEALTH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STEELCAS.csv
# Table 'STEELCAS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STERTOOLS.csv
# Table 'STERTOOLS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STLTECH.csv
# Table 'STLTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STOVEKRAFT.csv
# Table 'STOVEKRAFT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\STYLAMIND.csv
# Table 'STYLAMIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUBEXLTD.csv
# Table 'SUBEXLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUMICHEM.csv
# Table 'SUMICHEM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUMMITSEC.csv
# Table 'SUMMITSEC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUNDRMFAST.csv
# Table 'SUNDRMFAST' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUNPHARMA.csv
# Table 'SUNPHARMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUNTECK.csv
# Table 'SUNTECK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUPREMEIND.csv
# Table 'SUPREMEIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SUTLEJTEX.csv
# Table 'SUTLEJTEX' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SYMPHONY.csv
# Table 'SYMPHONY' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SYNGENE.csv
# Table 'SYNGENE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\SYRMA.csv
# Table 'SYRMA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TASTYBITE.csv
# Table 'TASTYBITE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TATACOMM.csv
# Table 'TATACOMM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TATACONSUM.csv
# Table 'TATACONSUM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TATASTEEL.csv
# Table 'TATASTEEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TATATECH.csv
# Table 'TATATECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TATVA.csv
# Table 'TATVA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TCI.csv
# Table 'TCI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TCIEXP.csv
# Table 'TCIEXP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TCS.csv
# Table 'TCS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TDPOWERSYS.csv
# Table 'TDPOWERSYS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TEGA.csv
# Table 'TEGA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TEJASNET.csv
# Table 'TEJASNET' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TEXRAIL.csv
# Table 'TEXRAIL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\THERMAX.csv
# Table 'THERMAX' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TIINDIA.csv
# Table 'TIINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TIMETECHNO.csv
# Table 'TIMETECHNO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TIMKEN.csv
# Table 'TIMKEN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TIRUMALCHM.csv
# Table 'TIRUMALCHM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TITAGARH.csv
# Table 'TITAGARH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TITAN.csv
# Table 'TITAN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TMB.csv
# Table 'TMB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TNPL.csv
# Table 'TNPL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TRACXN.csv
# Table 'TRACXN' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TRIDENT.csv
# Table 'TRIDENT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TRITURBINE.csv
# Table 'TRITURBINE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TRIVENI.csv
# Table 'TRIVENI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TTKPRESTIG.csv
# Table 'TTKPRESTIG' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TVSHLTD.csv
# Table 'TVSHLTD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TVSMOTOR.csv
# Table 'TVSMOTOR' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\TVSSCS.csv
# Table 'TVSSCS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UBL.csv
# Table 'UBL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UDS.csv
# Table 'UDS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UGROCAP.csv
# Table 'UGROCAP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UJJIVANSFB.csv
# Table 'UJJIVANSFB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ULTRACEMCO.csv
# Table 'ULTRACEMCO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UNICHEMLAB.csv
# Table 'UNICHEMLAB' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UNIONBANK.csv
# Table 'UNIONBANK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UNIPARTS.csv
# Table 'UNIPARTS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UNOMINDA.csv
# Table 'UNOMINDA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UPL.csv
# Table 'UPL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\USHAMART.csv
# Table 'USHAMART' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UTIAMC.csv
# Table 'UTIAMC' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\UTKARSHBNK.csv
# Table 'UTKARSHBNK' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VAIBHAVGBL.csv
# Table 'VAIBHAVGBL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VBL.csv
# Table 'VBL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VEDL.csv
# Table 'VEDL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VENUSREM.csv
# Table 'VENUSREM' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VERANDA.csv
# Table 'VERANDA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VGUARD.csv
# Table 'VGUARD' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VIJAYA.csv
# Table 'VIJAYA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VIPIND.csv
# Table 'VIPIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VISHNU.csv
# Table 'VISHNU' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VOLTAMP.csv
# Table 'VOLTAMP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VOLTAS.csv
# Table 'VOLTAS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VPRPL.csv
# Table 'VPRPL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VSSL.csv
# Table 'VSSL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VSTIND.csv
# Table 'VSTIND' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\VTL.csv
# Table 'VTL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\WELCORP.csv
# Table 'WELCORP' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\WELENT.csv
# Table 'WELENT' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\WHEELS.csv
# Table 'WHEELS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\WHIRLPOOL.csv
# Table 'WHIRLPOOL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\WINDLAS.csv
# Table 'WINDLAS' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\WIPRO.csv
# Table 'WIPRO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\XCHANGING.csv
# Table 'XCHANGING' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\YASHO.csv
# Table 'YASHO' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZAGGLE.csv
# Table 'ZAGGLE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZEEL.csv
# Table 'ZEEL' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZEEMEDIA.csv
# Table 'ZEEMEDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZENSARTECH.csv
# Table 'ZENSARTECH' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZFCVINDIA.csv
# Table 'ZFCVINDIA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZOTA.csv
# Table 'ZOTA' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZUARI.csv
# Table 'ZUARI' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZYDUSLIFE.csv
# Table 'ZYDUSLIFE' created successfully.
# Processing file: C:\Users\bomma\Desktop\Github\Mine Final CSVs\ZYDUSWELL.csv
# Table 'ZYDUSWELL' created successfully.
# Database creation process completed.

# %%
print("From Here Main Analysis Start")
# Out:
# From Here Main Analysis Start

# %%
import zipfile
import os

# --- Source file path ---
db_path = r"C:\Users\bomma\Desktop\Github\News Now\Final Analysis.db"

# --- Destination folder path ---
zip_folder = r"C:\Users\bomma\Desktop\Github\Final Zip"

# --- Ensure the folder exists ---
os.makedirs(zip_folder, exist_ok=True)

# --- Create ZIP file path in destination folder ---
zip_name = "Final Analysis.zip"
zip_path = os.path.join(zip_folder, zip_name)

# --- Compress the file ---
with zipfile.ZipFile(zip_path, 'w', zipfile.ZIP_DEFLATED) as zipf:
    zipf.write(db_path, os.path.basename(db_path))  # add only filename, not full path

print(f"File zipped successfully: {zip_path}")
# Out:
# File zipped successfully: C:\Users\bomma\Desktop\Github\Final Zip\Final Analysis.zip

# %%
# --- Telegram message + file sender (direct and simple) ---
import requests

# --- Your Telegram bot credentials ---
bot_token = '6935326572:AAGYtturdBCopuDFqSIvz88mmBv-0oVgvE0'
chat_id = '1178469727'

# --- File path ---
file_path = r"C:\Users\bomma\Desktop\Github\Final Zip\Final Analysis.zip"

# --- Message text ---
message = (
    "GitHub Rashmi: News Download and Extraction completed ✅\n"
    "SQLite database file attached.\n\n"
    "Thank you sir,\nSincerely,\nJanavi K"
)

# --- Function to send text message ---
def send_telegram_message(token, chat_id, message):
    """Send a Telegram message."""
    url = f"https://api.telegram.org/bot{token}/sendMessage"
    payload = {"chat_id": chat_id, "text": message}
    response = requests.post(url, json=payload)
    if response.status_code == 200:
        print("✅ Message sent successfully!")
    else:
        print(f"❌ Failed to send message: {response.status_code} - {response.text}")

# --- Function to send file ---
def send_telegram_file(token, chat_id, file_path, caption=None):
    """Send a file to Telegram chat."""
    url = f"https://api.telegram.org/bot{token}/sendDocument"
    with open(file_path, "rb") as f:
        files = {"document": f}
        data = {"chat_id": chat_id, "caption": caption or ""}
        response = requests.post(url, data=data, files=files)
    if response.status_code == 200:
        print("✅ File sent successfully!")
    else:
        print(f"❌ Failed to send file: {response.status_code} - {response.text}")

# --- Run both ---
send_telegram_message(bot_token, chat_id, message)
send_telegram_file(bot_token, chat_id, file_path, caption="Final Analysis Database File 📁")
# Out:
# ✅ Message sent successfully!
# ✅ File sent successfully!

# %%
print('from here only for laptop code run this is copy the files to google drive for access mobile codes')
